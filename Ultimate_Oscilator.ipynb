# %%
# load packages
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

#import yahoo_fin.stock_info as si
import pandas as pd
import ta
from ta import add_all_ta_features
 
# pull data from Yahoo Finance
# Download historical data for required stocks
#ticker = "MSFT"
#data = yf.download(ticker,dt.date.today()-dt.timedelta(3650),dt.datetime.today())

# %% [markdown]
# def long_period_df(ticker, period="60d", interval="5m", threads=True):
#     long_df = yf.download(
#         ticker,
#         period=period,
#         threads=threads
#     )
#     return long_df

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "1mo",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "5m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#data = long_period_df(ticker, period="1d", interval="5m", threads=True)

# %%
data
# Out:
#                               Open      High     Low     Close  Volume
# Datetime
# 2021-04-29 04:00:00-04:00  255.400  256.3100  255.05  256.1100       0
# 2021-04-29 04:05:00-04:00  256.000  256.3100  255.97  256.3000       0
# 2021-04-29 04:10:00-04:00  256.270  256.4900  256.18  256.3100       0
# 2021-04-29 04:15:00-04:00  256.300  256.3300  256.01  256.1000       0
# 2021-04-29 04:20:00-04:00  256.180  256.3200  256.18  256.3100       0
# 2021-04-29 04:25:00-04:00  256.320  256.3200  256.13  256.2500       0
# 2021-04-29 04:30:00-04:00  256.320  256.4900  256.24  256.4800       0
# 2021-04-29 04:35:00-04:00  256.480  256.4800  256.30  256.3200       0
# 2021-04-29 04:40:00-04:00  256.470  256.4800  256.30  256.3200       0
# 2021-04-29 04:45:00-04:00  256.340  256.3600  256.18  256.2600       0
# 2021-04-29 04:50:00-04:00  256.260  256.2700  256.16  256.2000       0
# 2021-04-29 04:55:00-04:00  256.200  256.2200  256.18  256.2000       0
# ...

# %%
data.shape
# Out:
# (22, 6)

# %%
# add technical analysis features
data = add_all_ta_features(
    data, open="Open", high="High", low="Low", close="Close", volume="Volume")
# Out:
# C:\Users\raque\anaconda3\envs\mlenv\lib\site-packages\ta\trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# C:\Users\raque\anaconda3\envs\mlenv\lib\site-packages\ta\trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-6d6982b3fe2d> in <module>
#       1 # add technical analysis features
#       2 data = add_all_ta_features(
# ----> 3     data, open="Open", high="High", low="Low", close="Close", volume="Volume")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\ta\wrapper.py in add_all_ta_features(df, open, high, low, close, volume, fillna, colprefix)
#     558     )
#     559     df = add_trend_ta(
# ...

# %%
data.momentum_uo.tail(5)

# %%
from ta.momentum import UltimateOscillator
